# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('IceCreamData.csv')
df['Temperature'] = df['Temperature'].round()
df['Revenue'] = df['Revenue'].round()

df
# Out:
#      Temperature  Revenue
# 0           25.0    535.0
# 1           26.0    625.0
# 2           28.0    661.0
# 3           21.0    488.0
# 4           12.0    316.0
# ..           ...      ...
# 495         22.0    525.0
# 496         33.0    756.0
# 497         13.0    306.0
# 498         22.0    566.0
# 499         29.0    656.0
#
# [500 rows x 2 columns]

# %%
plt.plot(df['Temperature'], df['Revenue'], 'r.-')
plt.ylabel('Sales US$')
plt.xlabel('Temperatura(fahrenheit)')
plt.title('Ice Cream Truck')
plt.yticks(df['Revenue'][250:550:50])
plt.xticks(df['Temperature'][1:100:10])
# Out:
# ([<matplotlib.axis.XTick at 0x286f0fd1690>,
# ...
#  [Text(26.0, 0, '26'),
#   Text(4.0, 0, '4'),
#   Text(15.0, 0, '15'),
#   Text(15.0, 0, '15'),
#   Text(9.0, 0, '9'),
#   Text(27.0, 0, '27'),
#   Text(12.0, 0, '12'),
#   Text(28.0, 0, '28'),
#   Text(15.0, 0, '15'),
#   Text(9.0, 0, '9')])
